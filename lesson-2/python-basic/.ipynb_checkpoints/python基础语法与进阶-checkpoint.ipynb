# %%
#单行注释
print("第一行")
print("第一行")
# Out:
# 第一行
# 第一行

# %%
#续行符
sum=1+2+3\
    +4+5+6
print(sum)
# Out:
# 21

# %%
#括号内可以直接换行
food=["面条","米饭",
      "薯条","汉堡"]
print(food)
# Out:
# ['面条', '米饭', '薯条', '汉堡']

# %%
'''缩进的核心
'''
if True:
    print("缩进四个空格或者一个tab键")
# Out:
# 缩进四个空格或者一个tab键

# %%
# 也可以使用在变量中
content='''
你好！我是gaolin，
你呢？
我是abc
'''
print(content)
# Out:
# 你好！我是gaolin，
# 你呢？
# 我是abc

# %%
x=10
print(id(x),type(x),x)
x=3.14
print(id(x),type(x),x)
# Out:
# 22242592 <class 'int'> 10
# 132544617276400 <class 'float'> 3.14

# %%
###标识符案例 PEP8使用下划线
student_name="小名"
studentAge=18

# %%
#python中关键字的查看
import keyword
#查看有哪些关键字
print(keyword.kwlist)
#查看有多少个关键字
print(len(keyword.kwlist))

#判断是否为关键字
print(keyword.iskeyword("for"))
print(keyword.iskeyword("end"))
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
# 35
# True
# False

# %%
#基本输出
print("Hello!AI")
print("Hello!","AI")
print("Hello","Ai",sep="!")
print("Hello",end="!")
print("AI")
# Out:
# Hello!AI
# Hello! AI
# Hello!Ai
# Hello!AI

# %%
# %格式化
name = "Alex"
age = 22
print("name: %s,age: %d" % (name,age))
print("name: %s,age: %.2f" % (name,age))

# str.format
print("name: {0},age:{1}".format(name,age))
print("name: {0},age:{1}".format(age,name))
print("name: {name},age:{age}".format(name=name,age=age))
print("name: {name},age:{age}".format(age=age,name=name))
print("{:*^20}".format("居中"))

#f-string
print(f"name={name},age={age}")
print(f"{3.1415926:.2f}")
print(f"{"剧中":*^20}")
# Out:
# name: Alex,age: 22
# name: Alex,age: 22.00
# name: Alex,age:22
# name: 22,age:Alex
# name: Alex,age:22
# name: Alex,age:22
# *********居中*********
# name=Alex,age=22
# 3.14
# *********剧中*********

# %%
#input输入
a=input("第一个输入：")
b=input("第二个输入：")
c=a+b
print(f"{a}+{b}={c}")
# Out:
# 第一个输入： 10
# 第二个输入： 20
# 10+20=1020

# %%
#input输入转换为数字
a=int(input("第一个输入："))
b=int(input("第二个输入："))
c=a+b
print(f"{a}+{b}={c}")
# Out:
# 第一个输入： 10
# 第二个输入： 20
# 10+20=30

# %%
#转义字符
print("i like\n you!")
print("\"gaolin\"")
print("gaolin\tstaronearth")
print("gao\\lin")
# Out:
# i like
#  you!
# "gaolin"
# gaolin	staronearth
# gao\lin

# %%
#大小写转换
#ch='a'
#upper=chr(ord(ch)-32)
#print(f"{ch}的大写是{upper}")

# %%
#浮点类型
print(0.1+0.2==0.3)
# Out:
# False

# %%
#浮点类型
import math
print(math.isclose(0.1+0.2,0.3))
# Out:
# True

# %%
#一些nath函数
print(round(0.322,2))
print(math.ceil(3.14))
print(math.floor(3.14))
print(pow(2,3))
print(math.sqrt(9))
# Out:
# 0.32
# 4
# 3
# 8
# 3.0
